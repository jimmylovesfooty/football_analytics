# %%
# Preferably in a conda or pip virtual environment, or a Docker container even (so that
# this won't affect the globally installed Python packages):
#!pip install bqplot fastparquet ipywidgets pyarrow tqdm qgrid
# Out:
# Collecting bqplot
#   Downloading bqplot-0.12.43-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting fastparquet
#   Downloading fastparquet-2024.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: ipywidgets in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (8.1.1)
# Requirement already satisfied: pyarrow in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (14.0.1)
# Requirement already satisfied: tqdm in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (4.66.1)
# Collecting qgrid
#   Downloading qgrid-1.3.1.tar.gz (889 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.2/889.2 kB 101.0 kB/s eta 0:00:0000:0100:03
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: traitlets>=4.3.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from bqplot) (5.14.0)
# Collecting traittypes>=0.0.6 (from bqplot)
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy>=1.10.4 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from bqplot) (1.26.2)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from bqplot) (2.2.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting fsspec (from fastparquet)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from fastparquet) (23.2)
# Requirement already satisfied: comm>=0.1.3 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: notebook>=4.0.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from qgrid) (7.0.6)
# Requirement already satisfied: decorator in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from notebook>=4.0.0->qgrid) (2.12.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from notebook>=4.0.0->qgrid) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from notebook>=4.0.0->qgrid) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from notebook>=4.0.0->qgrid) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from notebook>=4.0.0->qgrid) (6.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->bqplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->bqplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->bqplot) (2024.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (4.1.0)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (23.1.0)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.1.2)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (5.5.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.5.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (7.12.0)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (5.9.2)
# Requirement already satisfied: overrides in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (7.4.0)
# Requirement already satisfied: prometheus-client in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.19.0)
# Requirement already satisfied: pyzmq>=24 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.18.0)
# Requirement already satisfied: websocket-client in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.0.0->qgrid) (2.0.4)
# Requirement already satisfied: ipykernel in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.0.0->qgrid) (6.27.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.0.0->qgrid) (2.2.1)
# Requirement already satisfied: babel>=2.10 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (4.20.0)
# Requirement already satisfied: requests>=2.31 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (2.31.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.0.0->bqplot) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (0.13.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (4.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.2.1)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->qgrid) (2023.11.17)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (21.2.0)
# Requirement already satisfied: appnope in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.0.0->qgrid) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.0.0->qgrid) (1.8.0)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.0.0->qgrid) (1.5.8)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.0.0->qgrid) (5.9.6)
# Requirement already satisfied: webencodings in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.5.1)
# Requirement already satisfied: fqdn in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.5.1)
# Requirement already satisfied: isoduration in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.4)
# Requirement already satisfied: uri-template in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.5)
# Requirement already satisfied: pycparser in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.8.19.14)
# Downloading bqplot-0.12.43-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 515.0 kB/s eta 0:00:0000:0100:01
# Downloading fastparquet-2024.5.0-cp311-cp311-macosx_11_0_arm64.whl (683 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 683.5/683.5 kB 409.3 kB/s eta 0:00:00a 0:00:01
# Downloading cramjam-2.9.0-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 730.4 kB/s eta 0:00:0000:0100:01
# Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: qgrid
#   Building wheel for qgrid (setup.py) ... done
#   Created wheel for qgrid: filename=qgrid-1.3.1-py2.py3-none-any.whl size=1761252 sha256=b54298e39f83a42549187c8ab0ef0fe394b0fa053916ac99c85c5030538de873
#   Stored in directory: /Users/jamesdavies/Library/Caches/pip/wheels/7f/0f/d6/33b60aa35dbdc3d3e84c44b780c85e92d8767b698843f9e256
# Successfully built qgrid
# Installing collected packages: traittypes, fsspec, cramjam, fastparquet, bqplot, qgrid
# Successfully installed bqplot-0.12.43 cramjam-2.9.0 fastparquet-2024.5.0 fsspec-2024.10.0 qgrid-1.3.1 traittypes-0.2.1

# %%
cd soccermatics
# Out:
# /Users/jamesdavies/soccermatics

# %%
import os

import ipywidgets as widgets
import pandas as pd
import qgrid
from bqplot import (
    Figure,
    Image,
    LinearScale,
    Scatter,
)


DATA_DIR = os.path.join("<YOUR_PATH_TO_THE_ROOT_OF_THE_DATA_DIR>", "twelve-respovision-CL-final", "Data")

PITCH_LEGNTH = 105.0
PITCH_WIDTH = 68.0
OFFSET = 3.0
OFFSET_LENGTH = OFFSET / PITCH_LEGNTH
OFFSET_WIDTH = OFFSET / PITCH_WIDTH
X = [-OFFSET_LENGTH, 1 + OFFSET_LENGTH]
Y_rev = [-OFFSET_WIDTH, 1 + OFFSET_WIDTH]

# Used to fix displaying quirks.
WIDTH = 506.7
HEIGHT = 346.7
FACTOR = 1.8

home_team = "Manchester City"
away_team = "Inter"

team_colours = {
    home_team: '#6cabdd',
    away_team: '#010E80',
}

ball_colour = 'orange'

def transform_x_coordinates(x):
    return x / PITCH_LEGNTH * 100

def transform_y_coordinates(x):
    return 100 - (x / PITCH_WIDTH * 100)


class RadarViewWidget(widgets.VBox):
    def __init__(self, pitch_img='pitch.png'):
        super().__init__()
        self.pitch_img = pitch_img
        self.image = self.__init_image()
        self.home_scatter = self.__init_scatter()
        self.away_scatter = self.__init_scatter()
        self.ball_scatter = self.__init_scatter(size=64, selected_opacity=1.0)
        
        self.fig = Figure(
            marks=[self.image, self.home_scatter, self.away_scatter, self.ball_scatter],
            padding_x=0, padding_y=0,
        )
        self.fig.layout = widgets.Layout(width=f'{WIDTH * FACTOR}px', height=f'{HEIGHT * FACTOR}px')
        self.output = widgets.Output()
        
        self.children = [self.fig, self.output]

    def __init_image(self):
        image_path = os.path.abspath(self.pitch_img)

        with open(image_path, 'rb') as f:
            raw_image = f.read()
        ipyimage = widgets.Image(value=raw_image, format='png')

        scales_image = {'x': LinearScale(), 'y': LinearScale(reverse=True)}
        axes_options = {'x': {'visible': True}, 'y': {'visible': True}}

        image = Image(image=ipyimage, scales=scales_image, axes_options=axes_options)

        image.x = X
        image.y = Y_rev        
        return image
        
    def __init_scatter(self, size=128, selected_opacity=0.6, unselected_opacity=1.0):
        scales={'x': LinearScale(min=X[0], max=X[1]), 'y': LinearScale(min=Y_rev[0], max=Y_rev[1], reverse=True)}
        axes_options = {'x': {'visible': False}, 'y': {'visible': False}}

        scatter = Scatter(
            scales= scales, 
            default_size=size,
            interactions={'click': 'select'},
            selected_style={'opacity': selected_opacity, 'stroke': 'Black'},
            unselected_style={'opacity': unselected_opacity},
            axes_options=axes_options,
        )
        scatter.enable_move = False
        return scatter

    def output_data(self, _, data):
        new_x = round(data['point']['x'], 2)
        new_y = round(data['point']['y'], 2)
        
        self.output.clear_output()
        with self.output:
            print(f'Changed player coordinates to ({new_x}, {new_y})')
    
    def set_data(self, frameset):
        self.home_scatter.x = frameset['home_x']
        self.home_scatter.y = frameset['home_y']
        self.home_scatter.names = frameset['home_names'],
        self.home_scatter.colors = frameset['home_color']
        
        self.away_scatter.x = frameset['away_x']
        self.away_scatter.y = frameset['away_y']
        self.away_scatter.names=frameset['away_names'],
        self.away_scatter.colors=frameset['away_color']
        
        self.ball_scatter.x = frameset['ball_x']
        self.ball_scatter.y = frameset['ball_y']
        self.ball_scatter.colors = frameset['ball_color']

def frames_from_respovision(df_tracks):
    assert df_tracks.period.unique().tolist() == [1, 2]

    # Map `frame` and `period` to consecutive integeres, starting from 0. This is needed because, unfortunately, the same `frame`
    # number may appear in both periods, otherwise.

    frames = {}
    frame_id = 0
    frame_map = {}
    for period in [1, 2]:
        for frame in df_tracks[df_tracks.period == period].frame.unique().tolist():
            filter_conds = (df_tracks.frame == frame) & (df_tracks.period == period)

            home_x = (transform_x_coordinates(df_tracks[filter_conds & (df_tracks.team_name == home_team)].x)/100).values
            home_y = (transform_y_coordinates(df_tracks[filter_conds & (df_tracks.team_name == home_team)].y)/100).values
            home_names = (df_tracks[filter_conds & (df_tracks.team_name == home_team)].player).tolist()
            home_numbers = (df_tracks[filter_conds & (df_tracks.team_name == home_team)].jersey_number).tolist()
            ball_x = (transform_x_coordinates(df_tracks[filter_conds & (df_tracks.player == "ball")].x)/100).values
            ball_y = (transform_y_coordinates(df_tracks[filter_conds & (df_tracks.player == "ball")].y)/100).values
            away_x = (transform_x_coordinates(df_tracks[filter_conds & (df_tracks.team_name == away_team)].x)/100).values
            away_y = (transform_y_coordinates(df_tracks[filter_conds & (df_tracks.team_name == away_team)].y)/100).values
            away_names = (df_tracks[filter_conds & (df_tracks.team_name == away_team)].player).tolist()
            away_numbers = (df_tracks[filter_conds & (df_tracks.team_name == away_team)].jersey_number).tolist()

            if len(home_names) + len(away_names) == 0: continue

            frame_map[(period, frame)] = frame_id
            frames[frame_id] = {
                'home_x': home_x,
                'home_y': home_y,
                'home_names': home_numbers,
                'home_color': [team_colours[home_team]],
                'ball_x': ball_x,
                'ball_y': ball_y,
                'ball_color': [ball_colour],
                'away_x': away_x,
                'away_y': away_y,
                'away_names': away_numbers,
                'away_color': [team_colours[away_team]],
            }
            frame_id += 1
    return frames, frame_map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 import ipywidgets as widgets
#       4 import pandas as pd
# ----> 5 import qgrid
#       6 from bqplot import (
#       7     Figure,
#       8     Image,
#       9     LinearScale,
#      10     Scatter,
#      11 )
#      14 DATA_DIR = os.path.join("<YOUR_PATH_TO_THE_ROOT_OF_THE_DATA_DIR>", "twelve-respovision-CL-final", "Data")
#
# File /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages/qgrid/__init__.py:3
#       1 from ._version import version_info, __version__  # noqa F401
# ----> 3 from .grid import (
#       4     enable,
#       5     disable,
#       6     set_defaults,
#       7     on,
#       8     off,
#       9     set_grid_option,
#      10     show_grid,
#      11     QgridWidget,
#      12     QGridWidget,
#      13 )
#      16 def _jupyter_nbextension_paths():
#      17     return [
#      18         {
#      19             "section": "notebook",
#    (...)
#      23         }
#      24     ]
#
# File /opt/homebrew/anaconda3/envs/data-ltv-prediction/lib/python3.11/site-packages/qgrid/grid.py:524
#     520     else:
#     521         return str(x)
# --> 524 @widgets.register()
#     525 class QgridWidget(widgets.DOMWidget):
#     526     """
#     527     The widget class which is instantiated by the ``show_grid`` method. This
#     528     class can be constructed directly but that's not recommended because
#    (...)
#     562
#     563     """
#     565     _view_name = Unicode('QgridView').tag(sync=True)
#
# TypeError: register() missing 1 required positional argument: 'widget'

# %%
match_id = 18768058
df_tracks = pd.read_parquet(os.path.join('data', 'tracking_data', f"{match_id}_tracks.parquet"))
frames, frame_map = frames_from_respovision(df_tracks)
df = df_tracks[['frame', 'period']].copy()
df.loc['frame_id'] = 0
for (frame, period), v in frame_map.items():
    df.loc[(df.period == frame) & (df.frame == period), 'frame_id'] = v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 match_id = 18768058
#       2 df_tracks = pd.read_parquet(os.path.join('data', 'tracking_data', f"{match_id}_tracks.parquet"))
# ----> 3 frames, frame_map = frames_from_respovision(df_tracks)
#       4 df = df_tracks[['frame', 'period']].copy()
#       5 df.loc['frame_id'] = 0
#
# NameError: name 'frames_from_respovision' is not defined

# %%
widget = RadarViewWidget()

initial_frame = 0
initial_frameset = frames[initial_frame]
widget.set_data(initial_frameset)

play = widgets.Play(
    value=0,
    step=1,
    max=len(df_tracks),
    description="Press play",
    disabled=False
)
slider = widgets.IntSlider(max=max(frames.keys()))
widgets.jslink((play, 'value'), (slider, 'value'))

def change_data(change):
    widget.set_data(frames[change['new']])
    
slider.observe(change_data, names='value')
widgets.HBox([play, slider])

slider.value = initial_frame

qgrid.set_grid_option('maxVisibleRows', 10)
col_opts = { 
    'editable': False,
}

def on_row_selected(change):
    """callback for row selection: update selected points in scatter plot"""
    filtered_df = qgrid_widget.get_changed_df() 
    event = filtered_df.iloc[change.new]
    widget.set_data(frames[int(event['frame_id'].item())])
    slider.value = int(event['frame_id'].item())
   
        
qgrid_widget = qgrid.show_grid(df, show_toolbar=False, column_options=col_opts)
qgrid_widget.layout = widgets.Layout(width='920px')
   
qgrid_widget.observe(on_row_selected, names=['_selected_rows'])

display(widget)
display(widgets.HBox([play, slider]))
display(qgrid_widget)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 widget = RadarViewWidget()
#       3 initial_frame = 0
#       4 initial_frameset = frames[initial_frame]
#
# NameError: name 'RadarViewWidget' is not defined
